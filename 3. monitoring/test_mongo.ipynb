# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27018")

# %%
db = client.get_database("prediction_service")

# %%
data_collection = db.get_collection("data")

# %%
data = list(data_collection.find())

# %%
len(data)
# Out:
# 324

# %%
data
# Out:
# [{'_id': ObjectId('6302da8899692bd0eecb0517'),
#   'customerID': '9237-HQITU',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '151.65',
#   'prediction': 1},
#  {'_id': ObjectId('6302da8b99692bd0eecb0518'),
#   'customerID': '9237-HQITU',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '151.65',
#   'prediction': 1},
#  {'_id': ObjectId('6302da8c99692bd0eecb0519'),
#   'customerID': '9237-HQITU',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '151.65',
#   'prediction': 1},
#  {'_id': ObjectId('6302daa399692bd0eecb051a'),
#   'customerID': '9237-HQITU',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '151.65',
#   'prediction': 1},
#  {'_id': ObjectId('6302dca199692bd0eecb051b'),
#   'customerID': '6847-KJLTS',
#   'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 58,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 100.4,
#   'TotalCharges': '5749.8',
#   'Churn': 0,
#   'id': '85765fa5-75c4-45d1-ac27-61f7f83ace3c',
#   'prediction': 0},
#  {'_id': ObjectId('6302dca299692bd0eecb051c'),
#   'customerID': '9367-TCUYN',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 12,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 20.1,
#   'TotalCharges': '223.6',
#   'Churn': 0,
#   'id': '5e995661-5cd3-4389-8cad-8dfcbc575bdd',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcd899692bd0eecb051d'),
#   'customerID': '6847-KJLTS',
#   'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 58,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 100.4,
#   'TotalCharges': '5749.8',
#   'Churn': 0,
#   'id': '22025251-1e2e-4177-9bf9-bb8a4a5df2d7',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcda99692bd0eecb051e'),
#   'customerID': '9367-TCUYN',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 12,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 20.1,
#   'TotalCharges': '223.6',
#   'Churn': 0,
#   'id': 'ddb64c27-be27-4942-abc6-28c3a3c3cd56',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcdb99692bd0eecb051f'),
#   'customerID': '3733-ZEECP',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 22,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 51.1,
#   'TotalCharges': '1232.9',
#   'Churn': 0,
#   'id': '7930f12b-b063-42f9-a4ab-0c2786edc208',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcdc99692bd0eecb0520'),
#   'customerID': '5027-YOCXN',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 51,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 110.05,
#   'TotalCharges': '5686.4',
#   'Churn': 0,
#   'id': '9780a0f5-3b07-4325-b709-9efcf07552ea',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcdd99692bd0eecb0521'),
#   'customerID': '5928-QLDHB',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 9,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 76.25,
#   'TotalCharges': '684.85',
#   'Churn': 0,
#   'id': '307d7268-98c1-4caa-b70e-53801e7d00c9',
#   'prediction': 1},
#  {'_id': ObjectId('6302dcde99692bd0eecb0522'),
#   'customerID': '0233-FTHAV',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 60,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 79.2,
#   'TotalCharges': '4765',
#   'Churn': 0,
#   'id': 'f9c0e397-e373-4839-8169-5229b7de13b1',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcdf99692bd0eecb0523'),
#   'customerID': '1209-VFFOC',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 68,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 56.4,
#   'TotalCharges': '3948.45',
#   'Churn': 0,
#   'id': '1b3af83e-84be-4112-b036-81b363cc9ba6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce099692bd0eecb0524'),
#   'customerID': '4801-JZAZL',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 11,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 29.6,
#   'TotalCharges': '346.45',
#   'Churn': 0,
#   'id': 'b2cc317d-2819-4974-a6af-7bf7b4b016a6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce199692bd0eecb0525'),
#   'customerID': '5939-SXWHM',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 48,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 26.3,
#   'TotalCharges': '1245.05',
#   'Churn': 0,
#   'id': '7dba6e18-34c4-4c63-8218-56af892a479a',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce399692bd0eecb0526'),
#   'customerID': '9919-KNPOO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 21,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 94.3,
#   'TotalCharges': '1948.35',
#   'Churn': 0,
#   'id': '94493adc-3f1a-4dc2-bba8-fc746054e3f3',
#   'prediction': 1},
#  {'_id': ObjectId('6302dce499692bd0eecb0527'),
#   'customerID': '7926-IJOOU',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.3,
#   'TotalCharges': '19.3',
#   'Churn': 0,
#   'id': 'b51efe5e-d1db-4006-bf2a-491aeeba5c18',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce599692bd0eecb0528'),
#   'customerID': '1307-TVUFB',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 42,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 79.35,
#   'TotalCharges': '3344.1',
#   'Churn': 0,
#   'id': '569ae99a-59a4-46e6-b1f1-b7f71f964d8a',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce699692bd0eecb0529'),
#   'customerID': '1406-PUQVY',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 49.9,
#   'TotalCharges': '49.9',
#   'Churn': 0,
#   'id': '2034e7dd-253e-4a02-835b-dbc3ebe0cfc6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce799692bd0eecb052a'),
#   'customerID': '3144-AUDBS',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 6,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 49.15,
#   'TotalCharges': '270.8',
#   'Churn': 1,
#   'id': '8a85bf69-d7ac-485c-8df6-3182d2e09d4c',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce899692bd0eecb052b'),
#   'customerID': '4396-KLSEH',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 4,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 19.85,
#   'TotalCharges': '63',
#   'Churn': 0,
#   'id': '30299444-6c04-4ce0-8fb7-bbc58761220b',
#   'prediction': 0},
#  {'_id': ObjectId('6302dce999692bd0eecb052c'),
#   'customerID': '6990-YNRIO',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 65,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 108.65,
#   'TotalCharges': '6937.95',
#   'Churn': 1,
#   'id': 'ce2590bc-4933-4fb8-a500-b17ce06a1f64',
#   'prediction': 0},
#  {'_id': ObjectId('6302dceb99692bd0eecb052d'),
#   'customerID': '6142-VSJQO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 44.35,
#   'TotalCharges': '44.35',
#   'Churn': 1,
#   'id': '7d14d4df-9e1c-45a4-a4b9-f95bcad89b52',
#   'prediction': 1},
#  {'_id': ObjectId('6302dcec99692bd0eecb052e'),
#   'customerID': '0068-FIGTF',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 27,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 78.2,
#   'TotalCharges': '2078.95',
#   'Churn': 0,
#   'id': '8d5ce7ab-c02f-4543-98f5-6d37e6d02491',
#   'prediction': 0},
#  {'_id': ObjectId('6302dced99692bd0eecb052f'),
#   'customerID': '7471-WNSUF',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 60,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 24.15,
#   'TotalCharges': '1505.9',
#   'Churn': 0,
#   'id': 'd0f7e89e-9dbd-4024-b03b-bf55d8a12724',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcee99692bd0eecb0530'),
#   'customerID': '7030-FZTFM',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 72,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 110.9,
#   'TotalCharges': '7922.75',
#   'Churn': 0,
#   'id': 'b81bf707-640c-44e1-a270-61d07d1cf146',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcef99692bd0eecb0531'),
#   'customerID': '3173-WSSUE',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 71,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.7,
#   'TotalCharges': '1415.85',
#   'Churn': 0,
#   'id': 'f8d5f357-77d1-49fa-9357-823508ea91ab',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf099692bd0eecb0532'),
#   'customerID': '3066-RRJIO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 69.95,
#   'TotalCharges': '69.95',
#   'Churn': 1,
#   'id': '68197c7f-6401-45bc-9c72-cf8183b7d206',
#   'prediction': 1},
#  {'_id': ObjectId('6302dcf199692bd0eecb0533'),
#   'customerID': '0487-VVUVK',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 25,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 19.15,
#   'TotalCharges': '477.6',
#   'Churn': 0,
#   'id': '75f431db-0109-4eaf-9063-8a593383974e',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf399692bd0eecb0534'),
#   'customerID': '8975-SKGRX',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 71,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 116.1,
#   'TotalCharges': '8310.55',
#   'Churn': 0,
#   'id': '8eaf7515-5e49-4b25-b967-e534f7398212',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf499692bd0eecb0535'),
#   'customerID': '2451-YMUXS',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 67,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 64.55,
#   'TotalCharges': '4250.1',
#   'Churn': 0,
#   'id': '5249a90f-31c3-4830-bbaa-b247863f37a6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf599692bd0eecb0536'),
#   'customerID': '4186-ZBUEW',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 36,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '2511.95',
#   'Churn': 0,
#   'id': 'fbdf4b11-5353-4b9e-bad7-ddf25b88c232',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf699692bd0eecb0537'),
#   'customerID': '9518-XXBXE',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 10,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 75.3,
#   'TotalCharges': '720.45',
#   'Churn': 0,
#   'id': '07a3b822-378b-41a4-99a5-a77d356b3d27',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf799692bd0eecb0538'),
#   'customerID': '4325-NFSKC',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 19,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 90.6,
#   'TotalCharges': '1660',
#   'Churn': 1,
#   'id': '31b99403-4969-414f-99da-c70bc3c6bf4b',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf899692bd0eecb0539'),
#   'customerID': '2538-OIMXF',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 24.7,
#   'TotalCharges': '24.7',
#   'Churn': 0,
#   'id': 'be1ead9d-2e29-421f-8b09-ef7bf608ecb9',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcf999692bd0eecb053a'),
#   'customerID': '0074-HDKDG',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 25,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 61.6,
#   'TotalCharges': '1611',
#   'Churn': 0,
#   'id': '1f787fa1-d290-4430-b805-bb020a41255f',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcfa99692bd0eecb053b'),
#   'customerID': '1597-LHYNC',
#   'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 26,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 95.0,
#   'TotalCharges': '2497.2',
#   'Churn': 1,
#   'id': '70028eb8-830c-4025-9fd6-1e207c1d2ddd',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcfc99692bd0eecb053c'),
#   'customerID': '5842-POCOP',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 5,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 88.9,
#   'TotalCharges': '454.15',
#   'Churn': 1,
#   'id': '16785f1a-971c-4a49-8384-1d4144d8785f',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcfd99692bd0eecb053d'),
#   'customerID': '7354-OIJLX',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 9,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 75.85,
#   'TotalCharges': '724.65',
#   'Churn': 0,
#   'id': '47527ca6-6082-48b0-b109-2fdf229ddab8',
#   'prediction': 1},
#  {'_id': ObjectId('6302dcfe99692bd0eecb053e'),
#   'customerID': '7774-OJSXI',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 31,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 103.45,
#   'TotalCharges': '3066.45',
#   'Churn': 1,
#   'id': '097b0049-7c71-47ac-9bc9-4c84c8cef47f',
#   'prediction': 0},
#  {'_id': ObjectId('6302dcff99692bd0eecb053f'),
#   'customerID': '7077-XJMET',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 12,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 74.15,
#   'TotalCharges': '741.4',
#   'Churn': 0,
#   'id': '2d77070e-59f2-4f2f-b678-0995eab29277',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0099692bd0eecb0540'),
#   'customerID': '0927-LCSMG',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 7,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 74.65,
#   'TotalCharges': '544.55',
#   'Churn': 1,
#   'id': 'b6bd2646-c7f3-4519-8f86-2466997958d8',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0199692bd0eecb0541'),
#   'customerID': '6892-XPFPU',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 24,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 104.25,
#   'TotalCharges': '2433.9',
#   'Churn': 1,
#   'id': '7c3d9255-935e-4a97-8edb-dd6d8cda4bf5',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd0299692bd0eecb0542'),
#   'customerID': '3070-DVEYC',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 7,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 73.75,
#   'TotalCharges': '545.15',
#   'Churn': 1,
#   'id': '06118d7a-6061-402b-93b4-fe0b095e3bc6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0499692bd0eecb0543'),
#   'customerID': '0856-NAOES',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 6,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 60.9,
#   'TotalCharges': '414.1',
#   'Churn': 0,
#   'id': '66fe428c-7705-4a39-8e24-a40b1dfd14e5',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0599692bd0eecb0544'),
#   'customerID': '0404-AHASP',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 72,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.7,
#   'TotalCharges': '1421.9',
#   'Churn': 0,
#   'id': '7267bd63-3b89-493a-8fdb-a75a1e497ca9',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0699692bd0eecb0545'),
#   'customerID': '7636-XUHWW',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.9,
#   'TotalCharges': '33.7',
#   'Churn': 0,
#   'id': '473d322d-213c-4125-87d0-8af50a0cd36d',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0799692bd0eecb0546'),
#   'customerID': '5357-TZHPP',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 9,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 84.4,
#   'TotalCharges': '732.5',
#   'Churn': 1,
#   'id': '52b59ed8-20e7-4d8b-adb3-0a096dd4b7c9',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd0899692bd0eecb0547'),
#   'customerID': '6064-ZATLR',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 27,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 52.85,
#   'TotalCharges': '1498.65',
#   'Churn': 0,
#   'id': 'baa0f484-b9ab-4c5f-b208-642cdce3cd5e',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0999692bd0eecb0548'),
#   'customerID': '2208-MPXIO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 45,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 20.0,
#   'TotalCharges': '886.4',
#   'Churn': 0,
#   'id': 'd0f5077c-6fe7-4c2e-a6cc-f35e11795090',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0a99692bd0eecb0549'),
#   'customerID': '9225-BZLNZ',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 72,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 85.25,
#   'TotalCharges': '6083.1',
#   'Churn': 0,
#   'id': '7633f239-13b1-4a84-80e3-2b61c754dd29',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0b99692bd0eecb054a'),
#   'customerID': '3721-CNZHX',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 15,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 19.8,
#   'TotalCharges': '304.6',
#   'Churn': 0,
#   'id': 'e79146a8-cda1-4dea-afb8-8a9bac899a36',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd0d99692bd0eecb054b'),
#   'customerID': '2694-CIUMO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 12,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 79.55,
#   'TotalCharges': '958.25',
#   'Churn': 0,
#   'id': '54d5eb70-07c3-4639-a748-5ea4e4cd3cd4',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd0e99692bd0eecb054c'),
#   'customerID': '3223-WZWJM',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 26,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 83.95,
#   'TotalCharges': '2254.2',
#   'Churn': 1,
#   'id': 'ed99c3a7-3009-4679-acba-1b1733fa15dd',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd0f99692bd0eecb054d'),
#   'customerID': '2192-OZITF',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 45,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 73.55,
#   'TotalCharges': '3349.1',
#   'Churn': 0,
#   'id': '753f5455-37d5-4e17-aed1-3e853742d6a6',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1099692bd0eecb054e'),
#   'customerID': '6619-RPLQZ',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 45,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 20.85,
#   'TotalCharges': '892.15',
#   'Churn': 0,
#   'id': 'bd5f6815-5717-4f61-b7b6-928945e53c65',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1199692bd0eecb054f'),
#   'customerID': '5956-YHHRX',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 21,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 104.35,
#   'TotalCharges': '2271.85',
#   'Churn': 0,
#   'id': '4cafd718-77e0-445f-a5c8-93d49ed6b726',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd1299692bd0eecb0550'),
#   'customerID': '6035-RIIOM',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 54,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 97.2,
#   'TotalCharges': '5129.45',
#   'Churn': 0,
#   'id': '1776797d-5870-498e-b6ce-2ddeb260bd03',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1399692bd0eecb0551'),
#   'customerID': '1455-HFBXA',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 52,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 91.6,
#   'TotalCharges': '4627.8',
#   'Churn': 0,
#   'id': '66b3e6d8-75a2-4dfb-b959-ac484b7ed296',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1599692bd0eecb0552'),
#   'customerID': '4729-XKASR',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 24.75,
#   'TotalCharges': '24.75',
#   'Churn': 1,
#   'id': 'a7424702-70d1-4f76-9e0a-4bc4d273c6d4',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1699692bd0eecb0553'),
#   'customerID': '6103-LIANB',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 59,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 99.5,
#   'TotalCharges': '5861.75',
#   'Churn': 0,
#   'id': 'a0325e2c-5762-485d-8e5b-17ac355e9846',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1799692bd0eecb0554'),
#   'customerID': '1764-VUUMT',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 66,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.95,
#   'TotalCharges': '1269.1',
#   'Churn': 0,
#   'id': '331f58d4-4c8b-4c55-bd2e-29648389f522',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1899692bd0eecb0555'),
#   'customerID': '0375-HVGXO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 34.7,
#   'TotalCharges': '34.7',
#   'Churn': 1,
#   'id': 'eae49d59-d43b-4087-9eeb-8bcb57356b07',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd1999692bd0eecb0556'),
#   'customerID': '4256-ZWTZI',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 5,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 51.0,
#   'TotalCharges': '286.8',
#   'Churn': 0,
#   'id': '599aaa4c-d444-4372-a951-6ec5922bfe48',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1a99692bd0eecb0557'),
#   'customerID': '2070-FNEXE',
#   'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 7,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 76.45,
#   'TotalCharges': '503.6',
#   'Churn': 1,
#   'id': '273169b6-ea65-420f-9b7f-51ebd1ba4193',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1b99692bd0eecb0558'),
#   'customerID': '0362-ZBZWJ',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 36,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 84.9,
#   'TotalCharges': '3067.2',
#   'Churn': 1,
#   'id': 'bffb6434-69b5-453e-821e-898e6ffc28b4',
#   'prediction': 1},
#  {'_id': ObjectId('6302dd1d99692bd0eecb0559'),
#   'customerID': '8800-ZKRFW',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 30,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 107.5,
#   'TotalCharges': '3242.5',
#   'Churn': 0,
#   'id': '56cc1f1d-991f-45e8-bcef-9de379d3ee82',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1e99692bd0eecb055a'),
#   'customerID': '2474-BRUCM',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 40,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 101.85,
#   'TotalCharges': '4086.3',
#   'Churn': 1,
#   'id': 'dcff15a4-f6eb-4a4e-b7cb-b4909ca43c6b',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd1f99692bd0eecb055b'),
#   'customerID': '8942-DBMHZ',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 12,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 20.45,
#   'TotalCharges': '255.35',
#   'Churn': 0,
#   'id': '95cd9b15-e615-4101-ae58-02b8b10ecfea',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd2099692bd0eecb055c'),
#   'customerID': '4826-DXMUP',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 35,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 72.1,
#   'TotalCharges': '2495.15',
#   'Churn': 0,
#   'id': '8fb6fabe-ef72-42e2-9282-8655c52e0000',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd2199692bd0eecb055d'),
#   'customerID': '3508-CFVZL',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 71,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 111.3,
#   'TotalCharges': '7985.9',
#   'Churn': 0,
#   'id': 'd7d4ecae-c331-4f7e-8601-d61ebff5cc85',
#   'prediction': 0},
#  {'_id': ObjectId('6302dd2299692bd0eecb055e'),
#   'customerID': '1597-FZREH',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 2,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 76.4,
#   'TotalCharges': '160.8',
#   'Churn': 1,
#   'id': '9da0a275-ebe3-404b-ae6d-626601f53e08',
#   'prediction': 0},
# ...
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 26.3,
#   'TotalCharges': '1245.05',
#   'id': 'f9aa056a-a000-42dc-bfda-3c82ac0ed243',
#   'prediction': 0},
#  {'_id': ObjectId('6302dedd3ed1501650b253e9'),
#   'customerID': '9919-KNPOO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 21,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 94.3,
#   'TotalCharges': '1948.35',
#   'id': '1a5ea682-55b6-472b-8187-450bda7bc2a3',
#   'prediction': 1},
#  {'_id': ObjectId('6302dede3ed1501650b253ea'),
#   'customerID': '7926-IJOOU',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.3,
#   'TotalCharges': '19.3',
#   'id': '31e804f2-8a87-4b21-ba97-5ab6a67a433c',
#   'prediction': 0},
#  {'_id': ObjectId('6302dedf3ed1501650b253eb'),
#   'customerID': '1307-TVUFB',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 42,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 79.35,
#   'TotalCharges': '3344.1',
#   'id': 'e26610f7-805a-4dfa-8526-13be8085eda5',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee03ed1501650b253ec'),
#   'customerID': '1406-PUQVY',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 49.9,
#   'TotalCharges': '49.9',
#   'id': '472a248a-189f-404e-be43-bb340e07eb06',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee23ed1501650b253ed'),
#   'customerID': '3144-AUDBS',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 6,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 49.15,
#   'TotalCharges': '270.8',
#   'id': '03ae1e0f-431f-43dd-ab50-8d07fb6172e4',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee33ed1501650b253ee'),
#   'customerID': '4396-KLSEH',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 4,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 19.85,
#   'TotalCharges': '63',
#   'id': '4c8edc6a-377c-459f-899d-1e59b910161d',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee43ed1501650b253ef'),
#   'customerID': '6990-YNRIO',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 65,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 108.65,
#   'TotalCharges': '6937.95',
#   'id': 'b3645acd-f777-4b7b-9c11-0a374b285a57',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee53ed1501650b253f0'),
#   'customerID': '6142-VSJQO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 44.35,
#   'TotalCharges': '44.35',
#   'id': '16efcff4-1602-455c-bea4-b3bdb2df3b08',
#   'prediction': 1},
#  {'_id': ObjectId('6302dee63ed1501650b253f1'),
#   'customerID': '0068-FIGTF',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 27,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 78.2,
#   'TotalCharges': '2078.95',
#   'id': '59014012-ef9d-481d-8afe-86dc98e20b94',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee73ed1501650b253f2'),
#   'customerID': '7471-WNSUF',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 60,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'One year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 24.15,
#   'TotalCharges': '1505.9',
#   'id': 'b2e64cb8-d769-4f39-9941-da226949bdd1',
#   'prediction': 0},
#  {'_id': ObjectId('6302dee83ed1501650b253f3'),
#   'customerID': '7030-FZTFM',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 72,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 110.9,
#   'TotalCharges': '7922.75',
#   'id': 'd4049b90-68eb-4a1c-8b45-d36d740bd9ac',
#   'prediction': 0},
#  {'_id': ObjectId('6302deea3ed1501650b253f4'),
#   'customerID': '3173-WSSUE',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 71,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Credit card (automatic)',
#   'MonthlyCharges': 19.7,
#   'TotalCharges': '1415.85',
#   'id': '5bb98ee5-dab4-4fd6-9b71-911d7726efa8',
#   'prediction': 0},
#  {'_id': ObjectId('6302deeb3ed1501650b253f5'),
#   'customerID': '3066-RRJIO',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 69.95,
#   'TotalCharges': '69.95',
#   'id': 'ac2a5998-6fa4-42f0-8177-5089dfbde1e5',
#   'prediction': 1},
#  {'_id': ObjectId('6302deec3ed1501650b253f6'),
#   'customerID': '0487-VVUVK',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 25,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'No',
#   'OnlineSecurity': 'No internet service',
#   'OnlineBackup': 'No internet service',
#   'DeviceProtection': 'No internet service',
#   'TechSupport': 'No internet service',
#   'StreamingTV': 'No internet service',
#   'StreamingMovies': 'No internet service',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 19.15,
#   'TotalCharges': '477.6',
#   'id': '69d9b018-daa0-41cc-b4c8-2fc725c21950',
#   'prediction': 0},
#  {'_id': ObjectId('6302deed3ed1501650b253f7'),
#   'customerID': '8975-SKGRX',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 71,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 116.1,
#   'TotalCharges': '8310.55',
#   'id': '2071c0f9-5bba-4869-83db-1bb773165f8e',
#   'prediction': 0},
#  {'_id': ObjectId('6302deee3ed1501650b253f8'),
#   'customerID': '2451-YMUXS',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 67,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Two year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 64.55,
#   'TotalCharges': '4250.1',
#   'id': '697b95cc-06c4-4031-b71d-da5786892bef',
#   'prediction': 0},
#  {'_id': ObjectId('6302deef3ed1501650b253f9'),
#   'customerID': '4186-ZBUEW',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 36,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 70.7,
#   'TotalCharges': '2511.95',
#   'id': 'f57fb482-b477-4c81-8d51-6e54e3b4a327',
#   'prediction': 0},
#  {'_id': ObjectId('6302def03ed1501650b253fa'),
#   'customerID': '9518-XXBXE',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 10,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 75.3,
#   'TotalCharges': '720.45',
#   'id': '555bc7f7-4940-45ff-aa85-493bd738ec27',
#   'prediction': 0},
#  {'_id': ObjectId('6302def23ed1501650b253fb'),
#   'customerID': '4325-NFSKC',
#   'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 19,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 90.6,
#   'TotalCharges': '1660',
#   'id': '1720e743-0ccf-4508-b01c-26a391ce5f10',
#   'prediction': 0},
#  {'_id': ObjectId('6302def33ed1501650b253fc'),
#   'customerID': '2538-OIMXF',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'Yes',
#   'tenure': 1,
#   'PhoneService': 'No',
#   'MultipleLines': 'No phone service',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 24.7,
#   'TotalCharges': '24.7',
#   'id': '12241a88-1548-4bef-adaf-59b1303c1682',
#   'prediction': 0},
#  {'_id': ObjectId('6302def43ed1501650b253fd'),
#   'customerID': '0074-HDKDG',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 25,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'DSL',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Bank transfer (automatic)',
#   'MonthlyCharges': 61.6,
#   'TotalCharges': '1611',
#   'id': 'f8cbf406-d08f-44fa-b76f-59cc54035248',
#   'prediction': 0},
#  {'_id': ObjectId('6302def53ed1501650b253fe'),
#   'customerID': '1597-LHYNC',
#   'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 26,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 95.0,
#   'TotalCharges': '2497.2',
#   'id': '82fad7e0-b3c6-49df-9243-1b61913c0c61',
#   'prediction': 0},
#  {'_id': ObjectId('6302def63ed1501650b253ff'),
#   'customerID': '5842-POCOP',
#   'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 5,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'No',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'Yes',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'MonthlyCharges': 88.9,
#   'TotalCharges': '454.15',
#   'id': '73de469d-7f8e-4b6c-bb81-dfb2c9b1a366',
#   'prediction': 0},
#  {'_id': ObjectId('6302def73ed1501650b25400'),
#   'customerID': '7354-OIJLX',
#   'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 9,
#   'PhoneService': 'Yes',
#   'MultipleLines': 'Yes',
#   'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No',
#   'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'MonthlyCharges': 75.85,
#   'TotalCharges': '724.65',
#   'id': 'c0292034-ec8b-4d06-a044-2db5fa57d183',
#   'prediction': 1}]
